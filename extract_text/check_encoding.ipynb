# %%
from text_from_pdf import ExtractText
from krutidev_to_unicode import KrutidevToUnicode

# %%
text = ExtractText('/home/anirudh/Desktop/news_on_air_website_data_Text_Regional_Maithili_writereaddata_Bulletins_Text_Regional_2018_Dec_Regional-Patna-Maithily-1815-1820-20181210193927.pdf').get_text()

# %%
len(text)
# Out:
# 5266

# %%
lines = text.split('\n')

# %%
for i, l in enumerate(lines):
    print(KrutidevToUnicode.convert_to_unicode(l), i)
# Out:
# position of r -1
#                                                   दिनांक-10/12/2018  0
#  1
# position of r -1
#   2
# position of r -1
# प्रसार भारती  3
# position of r -1
# (भारत का लोक सेवा प्रसारक)  4
# position of r -1
# प्रादेशिक समाचार एकांश  5
# position of r -1
# आकाशवाणी, पटना  6
# position of r -1
#   7
#  8
# position of r -1
#   9
#  10
# position of r -1
# प्रसारणः- शाम 06ः15 बजे सँ                                अवधिः-05 मिनट         11
#  12
# position of r -1
#   13
# position of r -1
# दिन-सोम   14
# position of r -1
#   15
#  16
# position of r -1
#   17
#  18
# position of r -1
#   19
#  20
# position of r -1
#    21
# position of r -1
#   22
#  23
# position of r -1
#   24
#  25
# position of r 65
# probable position of r 64
# character at probable position ी
# ्
# केन्द्रीय मानव संसाधन विकास राज्यमंत्री आ राष्ट्रीय लोक समता पाटीर्क अध्यक्ष  26
#  27
# position of r -1
# उपेन्द्र  कुशवाहा  आइ  केन्द्रीय  मंत्रिमंडल  सॅ  त्याग-पत्र  दऽ  देलनि।  श्री  कुशवाहा  28
#  29
# position of r -1
# प्रधानमंत्री  नरेन्द्र  मोदी  के  अपन  त्याग-पत्र  पठा  देलनि।  ओ  भाजपाक  नेतृत्व  वला  30
#  31
# position of r -1
# एनडीए सॅ अलग हेबाक घोषणा कयलनि। नव दिल्ली मे संवाददाता लोकनि सॅ गपशप  32
#  33
# position of r 49
# probable position of r 48
# character at probable position ी
# श
# मे श्री कुशवाहा आरोप लगौलनि जे एनडीए मे हुनक पाटीर् के कमजोर करबाक कोशिश  34
#  35
# position of r 57
# probable position of r 56
# character at probable position ी
#
# कयल जाइत रहल। जदयू अध्यक्ष नीतीश कुमार पर सेहो ओ अपन पाटीर् के तोड़बाक  36
#  37
# position of r -1
# आरोप लगौलनि। श्री  कुशवाहा कहलनि जे आगांक रणनीति शीघ्रहि बनाओल जायत।  38
#  39
# position of r 5
# probable position of r 4
# character at probable position ड
# थ
# ओ  थडर्  फ्रंट  बनेबाक  बात  सेहो  कहलनि।  श्री  कुशवाहा  कहलनि  जे  महागठबंधन  मे  40
#  41
# position of r -1
# सम्मिलित हेबाक विकल्प पर सेहो विचार कयल जायत आ जौं आवश्यकता होयत तऽ  42
#  43
# position of r 15
# probable position of r 14
# character at probable position ी
# र
# असगरे हुनक पाटीर् चुनाव मे उतरि सकैत अछि। ओ स्पष्ट कयलनि जे लोकसभा चुनाव  44
#  45
# position of r 54
# probable position of r 53
# character at probable position ी
# ा
# काराकाट संसदीय क्षेत्रहि सॅ लड़ताह। दोसर दिस, हुनक पाटीर्क विधायक सुधांशु शेखर  46
#  47
# position of r 18
# probable position of r 17
# character at probable position थ
# न
# कहलनि जे ओ अपन समथर्क लोकनि संग असगरे एक-दू दिन मे जदयू मे सम्मिलित  48
#  49
# position of r -1
# हेताह।  हालांकि,  विधायक  ललन  पासवान  कहलनि  जे  हुनक  नेतृत्व  वला  गुट  असली  50
#  51
# position of r 23
# probable position of r 22
# character at probable position ी
# ्
# राष्ट्रीय लोक समता पाटीर् अछि। ओ कहलनि जे आगांक रणनीति पर ओ अपन समथर्क  52
#  53
# position of r 20
# probable position of r 19
# character at probable position श
# न
# लोकनि संग विचार-विमशर्क बाद कोनो निणर्य करताह।   54
#  55
# position of r -1
# ---------------------------------------------  56
#  57
# position of r -1
#   58
#  59
# position of r 18
# probable position of r 17
# character at probable position ी
# त
# भारतीय  जनता  पाटीर्  कहलक  अछि  जे  उपेन्द्र  कुशवाहाक  नेतृत्व  वला  राष्ट्रीय  60
#  61
# position of r 13
# probable position of r 12
# character at probable position ी
#
# लोक समता पाटीर् के एनडीए सॅ अलग हेबा सॅ गठबंधन पर कोनो असरि नहि पड़त।  62
#  63
# position of r 4
# probable position of r 3
# character at probable position ी
# ी
# पाटीर्क  प्रदेश  प्रवक्ता  निखिल  आनंद  कहलनि  जे  भाजपा  श्री  कुशवाहा  के  सदिखन  64
#  65
# position of r 58
# probable position of r 57
# character at probable position क
# म
# सम्मान दैत रहल अछि। ओ कहलनि जे गठबंधन सॅ अलग हेबाक ओ जे तकर् दऽ रहल  66
#  67
# position of r -1
# छथि ओ सत्य नहि अछि।   68
#  69
# position of r -1
# ---------------------------------------------  70
#  71
# position of r -1
#   72
#  73
# position of r 12
# probable position of r 11
# character at probable position व
# त
# भारतीय  रिजवर्  बैंकक  गवनर्र  उजिर्त  पटेल  अपन  पद  सॅ  आइ  त्याग-पत्र  दऽ  74
#  75
# position of r -1
# देलनि। श्री पटेल कहलनि जे ओ निजी कारण सॅ त्याग-पत्र देलनि अछि। श्री पटेल  76
#  77
# position of r 39
# probable position of r 38
# character at probable position व
# न
# कहलनि जे आरबीआई मे काज करब हुनका लेल गवर्क बात अछि।  78
#  79
# position of r -1
# ---------------------------------------------  80
#  81
# position of r -1
#   82
#  83
# position of r -1
# संसदक शीतकालीन सत्र काल्हि सॅ शुरू होयत। आठ जनवरी धरि चलय वला  84
#  85
# position of r 40
# probable position of r 39
# character at probable position ष
#
# एहि सत्र मे कुल बीस बैसार होयत। अगिला वषर् होबय वला लोकसभा चुनाव सॅ पूवर् ई  86
#  87
# position of r 32
# probable position of r 31
# character at probable position य
# द
# संसदक अंतिम सत्र होयत। संसदक कायर्वाही के सुचारू संचालन लेल आइ सवर्दलीय  88
#  89
# position of r -1
# बैसार  मे  प्रधानमंत्री  नरेन्द्र  मोदी  कहलनि  जे  सत्रक  क्रम  मे  देशक  लोक  सभक  आ  90
#  91
# position of r 25
# probable position of r 24
# character at probable position ा
# ा
# विकास सॅ जुड़ल विषय पर चचार् हेबाक चाही।    92
#  93
# position of r -1
# ---------------------------------------------  94
#  95
# position of r -1
#   96
#  97
# position of r -1
# मुजफ्फरपुर बालिका गृह यौन शोषण कांडक मुख्य आरोपी ब्रजेश ठाकुरक संग  98
#  99
# position of r 75
# probable position of r 74
# character at probable position ड
# य
# पटियाला  स्थित  जेल  मे  मारिपीटक  कोनो  सबूत  नहि  भेटल  अछि।  मेडिकल  बोडर्क  100
#  101
# position of r 5
# probable position of r 4
# character at probable position ट
# ो
# रिपोटर् देखलाक बाद उच्चतम न्यायालय कहलक जे रिपोटर् मे एहन किछु नहि अछि।  102
#  103
# position of r -1
# ब्रजेश ठाकुरक परिजन लोकनि प्रताड़नाक आरोप लगबैत हुनक मेडिकल जांच करेबाक  104
#  105
# position of r 19
# probable position of r 18
# character at probable position ष
# ग
# मांग कयने छलाह। शीषर् न्यायालय बालिका गृहक मकान के ध्वस्त करबाक सरकारक  106
#  107
# position of r 3
# probable position of r 2
# character at probable position र
# Z
# कारर्वाई पर रोक लगेबा सॅ सेहो नकारि देलक। एम्हर, आइ सॅ जिला प्रशासन आ नगर  108
#  109
# position of r 50
# probable position of r 49
# character at probable position व
# म
# निगमक टीम ब्रजेश ठाकुरक मकान के ध्वस्त करबा सॅ पूवर् संपत्ति सभक सूची बनायब  110
#  111
# position of r -1
# शुरू कऽ देलक अछि।    112
#  113
# position of r -1
# ---------------------------------------------  114
#  115
# position of r -1
#   116
#  117
# position of r -1
# पछवा  आ  हिमालय  क्षेत्र  सॅ  आबि  रहल  ठंडा  हवाक  कारण  मिथिलांचल  समेत  118
#  119
# position of r -1
# प्रदेशक अधिकांश क्षेत्र मे तापमान खसल अछि। मौसम विज्ञान केन्द्रक अनुसार अगिला  120
#  121
# position of r -1
# एक सप्ताह मे अधिकतम तापमान दू सॅ तीन डिग्री सेल्सियस आओर खसबाक संभावना  122
#  123
# position of r -1
# अछि।  मौसम  विभाग  कहलक  अछि  जे  सबेरे  आ  सांझ  मे  ठंडाक  संग  कनकनीक  124
#  125
# position of r -1
# अहसास होयत। सबेर मे कुहेस सेहो लागल रहत।     126
#  127
# position of r -1
# ---------------------------------------------  128
#  129
# position of r -1
#   130
#  131
# position of r -1
# नेपालक ऐतिहासिक नगर जनकपुर मे राम आ सीता विवाहक समारोह शुरू भऽ  132
#  133
# position of r -1
# गेल  अछि।  सप्ताह  भरि  चलय  वला  एहि  समारोह  मे  राम-सीता  विवाहक  विभिन्न  134
#  135
# position of r -1
# अनुष्ठान आयोजित कयल जा रहल अछि। एम्हर, सीतामढ़ीक पुनौराधाम मे सेहो विवाह  136
#  137
# position of r -1
# पंचमी  के  लऽकऽ  तैयारी  चलि  रहल  अछि।  परसू  बुध  दिन  विवाह  पंचमीक  आयोजन  138
#  139
# position of r -1
# कयल जायत। एकर अतिरिक्त मिथिलांचलक आनो ठाकुरबाड़ी आ मंदिर मे एहि अवसर  140
#  141
# position of r 16
# probable position of r 15
# character at probable position च
# व
# पर विशेष पूजा-अचर्ना कयल जायत।   142
#  143
# position of r -1
# ---------------------------------------------  144
#  145
# position of r -1
#   146
#  147
# position of r -1
# सुपौल  जिलाक  वीरपुर  थाना  क्षेत्रक  कोसी  तटबंध  लग  सॅ  एसएसबीक  जवान  148
#  149
# position of r -1
# लोकनि बाईस सय बोतल नेपाली शराबक संग एक व्यक्ति के गिरफ्तार कयलक अछि।  150
#  151
# position of r 62
# probable position of r 61
# character at probable position ट
# ज
# मुजफ्फरपुर जिलाक फुकौली आउट पोस्टक बलिया चैक सॅ पुलिस बीस काटर्न शराब  152
#  153
# position of r -1
# बरामद कयलक अछि।   154
#  155
# position of r -1
# ---------------------------------------------  156
#  157
# position of r -1
#   158
#  159
# position of r 49
# probable position of r 48
# character at probable position घ
# ा
# सीतामढ़ी  जिलाक  रीगा  मे  एक  आॅटोरिक्शा  के  दुघर्टनाग्रस्त  भऽ  गेला  सॅ  एक  160
#  161
# position of r -1
# युवतीक  घटनास्थले  पर  मृत्यु  भऽ  गेल,  जखनकि  दस  आन  गोटे  घायल  भऽ  गेलाह।  162
#  163
# position of r -1
# ओतहि, मुजफ्फरपुरक सरैया थाना क्षेत्रक ब्लाॅक मोड़ लग आॅटोरिक्शा के उनटि गेला सॅ  164
#  165
# position of r -1
# चालकक घटनास्थले पर मृत्यु भऽ गेल जखनकि तीन महिला गंभीर रूप सॅ घायल भऽ  166
#  167
# position of r -1
# गेलीह।   168
#  169
# position of r -1
# ---------------------------------------------  170
#  171
# position of r -1
#   172
#  173
# position of r -1
# खगड़िया जिलाक गोगरी थाना क्षेत्रक गोगरी बाजार स्थित एक कुरियर कंपनी  174
#  175
# position of r -1
# सॅ किछु अपराधी हथियारक बल पर साढ़े तीन लाख टाका लूटि लेलक। दोसर दिस,  176
#  177
# position of r -1
# वैशाली जिलाक बिद्दुपुर थाना क्षेत्रक मायाराम बाजार स्थित  एक  आभूषण दोकान सॅ  178
#  179
# position of r -1
# किछु चोर करीब अढाई लाख टाका मूल्यक आभूषण चोरी कऽ लेलक।   180
#  181
# position of r -1
# ---------------------------------------------  182
#  183
# position of r -1
#   184
#  185
# position of r 16
# probable position of r 15
# character at probable position य
# स
# सहरसा मे आशा कायर्कतार् लोकनि मानदेय बढ़ेबा आ अपन आनो मांगक समथर्न  186
#  187
# position of r 27
# probable position of r 26
# character at probable position श
# आ
# मे आइ समाहरणालयक सोझा प्रदशर्न कयलनि।   188
#  189
# position of r -1
# ---------------------------------------------  190
#  191
# position of r -1
# एहि संग आकाशवाणी, दरभंगा सँ प्रसारित संवादक ई अंक समाप्त भेल।  192
#  193
# position of r -1
#   194
#  195
# position of r -1
#  196

# %%
lines[26]
# Out:
# 'dsUnzh; ekuo lalk/ku fodkl jkT;ea=h vk jk"Vªh; yksd lerk ikVhZd v/;{k '

# %%
KrutidevToUnicode.convert_to_unicode(lines[29])
# Out:
# ''

# %%
KrutidevToUnicode.convert_to_unicode('ikVhZd')
# Out:
# ---------------position of r---------------- 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_17038/2697428284.py in <module>
# ----> 1 KrutidevToUnicode.convert_to_unicode('ikVhZd')
#
# ~/ekstep-speech-recognition/common_scripts/extract_text/krutidev_to_unicode.py in convert_to_unicode(krutidevString)
#     165
#     166             modifiedSubstring = krutidevString[sthiti1:sthiti2]
# --> 167             unicodeString += KrutidevToUnicode.do_convert(modifiedSubstring)
#     168
#     169         return unicodeString
#
# ~/ekstep-speech-recognition/common_scripts/extract_text/krutidev_to_unicode.py in do_convert(krutidevPart)
#     134                     charecter_at_probable_position_of_half_r = processPart[probable_position_of_half_r]
#     135
# --> 136                 charecter_to_be_replaced = processPart[
#     137                     probable_position_of_half_r, (position_of_R - probable_position_of_half_r)]
#     138                 new_replacement_string = "र्" + charecter_to_be_replaced
#
# TypeError: string indices must be integers

# %%
t = 'ikVhZd'

# %%
t[4:5]
# Out:
# 'Z'
